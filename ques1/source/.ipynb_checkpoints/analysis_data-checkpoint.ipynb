# %%
import pandas
import matplotlib.pyplot as mplt
import seaborn as sb
import numpy as ny

# %%
dframe = pandas.read_csv('../clean_data/clean_frailty.csv', index_col=0)

# %%
ax = sb.heatmap(dframe.corr(), cmap="YlGnBu", linewidths = 0.30, annot = True)
fig = ax.get_figure()
fig.savefig("../output/heatmap_of_Grip_Strength_Distribution.png")
